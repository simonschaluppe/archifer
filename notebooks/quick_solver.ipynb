# %%
import pandas as pd
import pulp as pl
from pathlib import Path
import matplotlib.pyplot as plt
import yaml

# %%
archetypes_path =Path("../data/archetypes_v1.xlsx")
config_path = Path("constraints.yaml")

# ---------------------------------------------------
# 1) Daten einlesen
# ---------------------------------------------------
df = pd.read_excel(archetypes_path)
df = df.set_index("archetype_id")  # Index: Archetyp-ID [file:2]

# vorbereitete thermische Endenergie (Heizen + DHW)
df["E_therm_MWhyr"] = (
    df["E_final_heating_MWhyr"] + df["E_final_dhw_MWhyr"]
)  # [file:2]

idx = df.index.tolist()

# ---------------------------------------------------
# 2) Konfiguration einlesen
# ---------------------------------------------------
with open(config_path, "r", encoding="utf-8") as f:
    cfg = yaml.safe_load(f)

targets = cfg.get("targets", {})
weights = cfg.get("weights", {})
constraints_cfg = cfg.get("constraints", [])

# %%
cfg
# Out:
# {'targets': {'Af_total': 878085,
#   'share_residential_Af': 0.61,
#   'share_energy_therm': {'fossil': 0.31,
#    'biogene': 0.37,
#    'district_heat': 0.16,
#    'heat_pump': 0.15}},
#  'weights': {'Af_total': 10,
#   'share_residential_Af': 10,
#   'share_energy_therm': 100},
#  'constraints': [{'name': 'Af_total',
#    'type': 'sum',
#    'column': 'Af_m2',
#    'hard': False,
#    'target': 'Af_total'},
#   {'name': 'share_residential_Af',
#    'type': 'share',
#    'column': 'Af_m2',
#    'predicate': "usage_simplified == 'residential'",
#    'hard': False,
#    'target': 'share_residential_Af'},
#   {'name': 'share_energy_therm',
#    'type': 'share_group',
#    'column': 'E_therm_MWhyr',
#    'categories': {'fossil': "energy_carrier_primary == 'fossil'",
#     'biogene': "energy_carrier_primary == 'biogene'",
#     'district_heat': "energy_carrier_primary == 'district_heat'",
#     'heat_pump': "energy_carrier_primary == 'heat_pump'"},
#    'hard': False,
#    'targets': 'share_energy_therm'}]}

# %%
# ---------------------------------------------------
# 3) Modell und Variablen
# ---------------------------------------------------
model = pl.LpProblem("Archetype_Inference", pl.LpMinimize)

# Gewichte / Anzahlen der Archetypen
w = pl.LpVariable.dicts("w", idx, lowBound=0, cat="Integer") # hier cat = "Continuous" für LP-Relaxation

# Slack-Variablen sammeln (pro Constraint-Name oder Gruppen-Element)
slack_pos = {}
slack_neg = {}

# %%
# ---------------------------------------------------
# 4) Constraints aus YAML kompilieren
# ---------------------------------------------------
for c in constraints_cfg:
    name = c["name"]
    ctype = c["type"]
    hard = c.get("hard", False)

    # Ziel(e) auflösen
    # - für 'sum' oder 'share' mit target: einfacher Wert oder String-Referenz
    # - für 'share_group' mit targets: dict in targets
    if ctype in ["sum", "share"]:
        if isinstance(c.get("target"), str):
            target_value = targets[c["target"]]
        else:
            target_value = c["target"]
    elif ctype == "share_group":
        # targets: Name des Dicts in 'targets'
        target_group_name = c["targets"]
        target_group = targets[target_group_name]
    else:
        raise ValueError(f"Unknown constraint type: {ctype}")

    # Serie/Spalte für Aggregation
    column = c["column"]
    series = df[column].astype(float)

    if ctype == "sum":
        # Summe über alle
        expr = pl.lpSum(w[i] * series[i] for i in idx)
        if hard:
            model += expr == target_value, name
        else:
            s_pos = pl.LpVariable(f"s_{name}_pos", lowBound=0)
            s_neg = pl.LpVariable(f"s_{name}_neg", lowBound=0)
            slack_pos[name] = s_pos
            slack_neg[name] = s_neg
            model += expr - target_value == s_pos - s_neg, name

    elif ctype == "share":
        predicate = c["predicate"]
        sel_idx = df.query(predicate).index
        expr_num = pl.lpSum(w[i] * series[i] for i in sel_idx)
        expr_den = pl.lpSum(w[i] * series[i] for i in idx)
        if hard:
            model += expr_num - target_value * expr_den == 0, name
        else:
            s_pos = pl.LpVariable(f"s_{name}_pos", lowBound=0)
            s_neg = pl.LpVariable(f"s_{name}_neg", lowBound=0)
            slack_pos[name] = s_pos
            slack_neg[name] = s_neg
            model += expr_num - target_value * expr_den == s_pos - s_neg, name

    elif ctype == "share_group":
        # categories: dict {cat_name: predicate}
        categories = c["categories"]
        for cat_name, predicate in categories.items():
            sub_name = f"{name}_{cat_name}"
            target_share = target_group[cat_name]

            sel_idx = df.query(predicate).index
            expr_num = pl.lpSum(w[i] * series[i] for i in sel_idx)
            expr_den = pl.lpSum(w[i] * series[i] for i. in idx)

            if hard:
                model += expr_num - target_share * expr_den == 0, sub_name
            else:
                s_pos = pl.LpVariable(f"s_{sub_name}_pos", lowBound=0)
                s_neg = pl.LpVariable(f"s_{sub_name}_neg", lowBound=0)
                slack_pos[sub_name] = s_pos
                slack_neg[sub_name] = s_neg
                model += (
                    expr_num - target_share * expr_den == s_pos - s_neg
                ), sub_name

    else:
        raise ValueError(f"Unknown constraint type: {ctype}")
    
    ## ctype erweiterbar für z.B. histogram, crosstab, bound, ratio, scenario_toggle
# Out:
#   Cell In[25], line 63
#     expr_den = pl.lpSum(w[i] * series[i] for i. in idx)
#                                                 ^
# SyntaxError: 'in' expected after for-loop variables

# %%
# ---------------------------------------------------
# 5) Zielfunktion aus Slack-Variablen
# ---------------------------------------------------
objective_terms = []

for name in slack_pos:
    # einfache Zuordnung der Gewichte
    if name == "Af_total":
        alpha = weights.get("Af_total", 1.0)
    elif name == "share_residential_Af":
        alpha = weights.get("share_residential_Af", 1.0)
    elif name.startswith("share_energy_therm_"):
        alpha = weights.get("share_energy_therm", 1.0)
    else:
        alpha = 1.0

    objective_terms.append(alpha * (slack_pos[name] + slack_neg[name]))

if objective_terms:
    model += pl.lpSum(objective_terms)
else:
    model += 0

# %%
model
# Out:
# Archetype_Inference:
# MINIMIZE
# 10*s_Af_total_neg + 10*s_Af_total_pos + 100*s_share_energy_therm_biogene_neg + 100*s_share_energy_therm_biogene_pos + 100*s_share_energy_therm_district_heat_neg + 100*s_share_energy_therm_district_heat_pos + 100*s_share_energy_therm_fossil_neg + 100*s_share_energy_therm_fossil_pos + 100*s_share_energy_therm_heat_pump_neg + 100*s_share_energy_therm_heat_pump_pos + 10*s_share_residential_Af_neg + 10*s_share_residential_Af_pos + 0.0
# SUBJECT TO
# Af_total: s_Af_total_neg - s_Af_total_pos + 210.08 w_EFH_III_1945_59_biogene
#  + 210.08 w_EFH_III_1945_59_dh + 210.08 w_EFH_III_1945_59_fossil
#  - 16.4973587338 w_RH_I_Bis_1919_reno_fossil
#  - 5.38913718638 w_RH_I_Bis_1919_reno_hp
#  - 18.5801028774 w_RH_VIII__2020_biogene - 14.2194664878 w_RH_VIII__2020_dh
#  - 14.2194664878 w_RH_VIII__2020_fossil - 4.64502571934 w_RH_VIII__2020_hp
#  - 31.4755312192 w_RH_VII_2000_20_biogene - 24.0884167494 w_RH_VII_2000_20_dh
#  - 26.2296093493 w_RH_VII_2000_20_fossil - 7.8688828048 w_RH_VII_2000_20_hp
#  - 46.5406661493 w_RH_VI_1990_99_biogene - 35.6178567469 w_RH_VI_1990_99_dh
#  - 43.631874515 w_RH_VI_1990_99_fossil - 11.6351665373 w_RH_VI_1990_99_hp
#  - 21.0338230101 w_RH_VI_1990_99_reno_biogene
#  - 16.0973135281 w_RH_VI_1990_99_reno_dh
#  - 16.0973135281 w_RH_VI_1990_99_reno_fossil
#  - 5.25845575252 w_RH_VI_1990_99_reno_hp - 67.468055367 w_RH_V_1980_89_biogene
#  - 51.6337158421 w_RH_V_1980_89_dh - 63.2513019066 w_RH_V_1980_89_fossil
#  - 16.8670138418 w_RH_V_1980_89_hp - 22.0914554486 w_RH_V_1980_89_reno_biogene
#  - 16.9067261086 w_RH_V_1980_89_reno_dh
#  - 16.9067261086 w_RH_V_1980_89_reno_fossil
#  - 5.52286386215 w_RH_V_1980_89_reno_hp = 0
#
# VARIABLES
# s_Af_total_neg Continuous
# s_Af_total_pos Continuous
# s_share_energy_therm_biogene_neg Continuous
# s_share_energy_therm_biogene_pos Continuous
# s_share_energy_therm_district_heat_neg Continuous
# s_share_energy_therm_district_heat_pos Continuous
# s_share_energy_therm_fossil_neg Continuous
# s_share_energy_therm_fossil_pos Continuous
# s_share_energy_therm_heat_pump_neg Continuous
# s_share_energy_therm_heat_pump_pos Continuous
# s_share_residential_Af_neg Continuous
# s_share_residential_Af_pos Continuous
# 0 <= w_EFH_III_1945_59_biogene Integer
# 0 <= w_EFH_III_1945_59_dh Integer
# 0 <= w_EFH_III_1945_59_fossil Integer
# 0 <= w_EFH_III_1945_59_hp Integer
# 0 <= w_EFH_III_1945_59_reno_biogene Integer
# 0 <= w_EFH_III_1945_59_reno_dh Integer
# 0 <= w_EFH_III_1945_59_reno_fossil Integer
# 0 <= w_EFH_III_1945_59_reno_hp Integer
# 0 <= w_EFH_II_1920_44_biogene Integer
# 0 <= w_EFH_II_1920_44_dh Integer
# 0 <= w_EFH_II_1920_44_fossil Integer
# 0 <= w_EFH_II_1920_44_hp Integer
# 0 <= w_EFH_II_1920_44_reno_biogene Integer
# 0 <= w_EFH_II_1920_44_reno_dh Integer
# 0 <= w_EFH_II_1920_44_reno_fossil Integer
# 0 <= w_EFH_II_1920_44_reno_hp Integer
# 0 <= w_EFH_IV_1960_79_biogene Integer
# 0 <= w_EFH_IV_1960_79_dh Integer
# 0 <= w_EFH_IV_1960_79_fossil Integer
# 0 <= w_EFH_IV_1960_79_hp Integer
# 0 <= w_EFH_IV_1960_79_reno_biogene Integer
# 0 <= w_EFH_IV_1960_79_reno_dh Integer
# 0 <= w_EFH_IV_1960_79_reno_fossil Integer
# 0 <= w_EFH_IV_1960_79_reno_hp Integer
# 0 <= w_EFH_I_Bis_1919_biogene Integer
# 0 <= w_EFH_I_Bis_1919_dh Integer
# 0 <= w_EFH_I_Bis_1919_fossil Integer
# 0 <= w_EFH_I_Bis_1919_hp Integer
# 0 <= w_EFH_I_Bis_1919_reno_biogene Integer
# 0 <= w_EFH_I_Bis_1919_reno_dh Integer
# 0 <= w_EFH_I_Bis_1919_reno_fossil Integer
# 0 <= w_EFH_I_Bis_1919_reno_hp Integer
# 0 <= w_EFH_VIII__2020_biogene Integer
# 0 <= w_EFH_VIII__2020_dh Integer
# 0 <= w_EFH_VIII__2020_fossil Integer
# 0 <= w_EFH_VIII__2020_hp Integer
# 0 <= w_EFH_VII_2000_20_biogene Integer
# 0 <= w_EFH_VII_2000_20_dh Integer
# 0 <= w_EFH_VII_2000_20_fossil Integer
# 0 <= w_EFH_VII_2000_20_hp Integer
# 0 <= w_EFH_VI_1990_99_biogene Integer
# 0 <= w_EFH_VI_1990_99_dh Integer
# 0 <= w_EFH_VI_1990_99_fossil Integer
# 0 <= w_EFH_VI_1990_99_hp Integer
# 0 <= w_EFH_VI_1990_99_reno_biogene Integer
# 0 <= w_EFH_VI_1990_99_reno_dh Integer
# 0 <= w_EFH_VI_1990_99_reno_fossil Integer
# 0 <= w_EFH_VI_1990_99_reno_hp Integer
# 0 <= w_EFH_V_1980_89_biogene Integer
# 0 <= w_EFH_V_1980_89_dh Integer
# 0 <= w_EFH_V_1980_89_fossil Integer
# 0 <= w_EFH_V_1980_89_hp Integer
# 0 <= w_EFH_V_1980_89_reno_biogene Integer
# 0 <= w_EFH_V_1980_89_reno_dh Integer
# 0 <= w_EFH_V_1980_89_reno_fossil Integer
# 0 <= w_EFH_V_1980_89_reno_hp Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_1860___1978_biogene Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_1860___1978_dh Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_1860___1978_fossil Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_1860___1978_hp Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_1979___2009_biogene Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_1979___2009_dh Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_1979___2009_fossil Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_1979___2009_hp Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_2010___2030_biogene Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_2010___2030_dh Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_2010___2030_fossil Integer
# 0 <= w_IWU_Culture_and_Leisure_(5)_2010___2030_hp Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_1860___1978_biogene Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_1860___1978_dh Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_1860___1978_fossil Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_1860___1978_hp Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_1979___2009_biogene Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_1979___2009_dh Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_1979___2009_fossil Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_1979___2009_hp Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_2010___2030_biogene Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_2010___2030_dh Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_2010___2030_fossil Integer
# 0 <= w_IWU_Hotels,_Boarding,_Restaurants_or_Catering_(7)_2010___2030_hp Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_1860___1978_biogene Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_1860___1978_dh Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_1860___1978_fossil Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_1860___1978_hp Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_1979___2009_biogene Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_1979___2009_dh Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_1979___2009_fossil Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_1979___2009_hp Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_2010___2030_biogene Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_2010___2030_dh Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_2010___2030_fossil Integer
# 0 <= w_IWU_Office,_Administrative_or_Government_Buildings_2010___2030_hp Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_1860___1978_biogene Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_1860___1978_dh Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_1860___1978_fossil Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_1860___1978_hp Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_1979___2009_biogene Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_1979___2009_dh Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_1979___2009_fossil Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_1979___2009_hp Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_2010___2030_biogene Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_2010___2030_dh Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_2010___2030_fossil Integer
# 0 <= w_IWU_Production,_Workshop,_Warehouse_or_Operations_(8)_2010___2030_hp Integer
# 0 <= w_IWU_Trade_Buildings_(9)_1860___1978_biogene Integer
# 0 <= w_IWU_Trade_Buildings_(9)_1860___1978_dh Integer
# 0 <= w_IWU_Trade_Buildings_(9)_1860___1978_fossil Integer
# 0 <= w_IWU_Trade_Buildings_(9)_1860___1978_hp Integer
# 0 <= w_IWU_Trade_Buildings_(9)_1979___2009_biogene Integer
# 0 <= w_IWU_Trade_Buildings_(9)_1979___2009_dh Integer
# 0 <= w_IWU_Trade_Buildings_(9)_1979___2009_fossil Integer
# 0 <= w_IWU_Trade_Buildings_(9)_1979___2009_hp Integer
# 0 <= w_IWU_Trade_Buildings_(9)_2010___2030_biogene Integer
# 0 <= w_IWU_Trade_Buildings_(9)_2010___2030_dh Integer
# 0 <= w_IWU_Trade_Buildings_(9)_2010___2030_fossil Integer
# 0 <= w_IWU_Trade_Buildings_(9)_2010___2030_reno_hp Integer
# 0 <= w_MWB_III_1945_59_biogene Integer
# 0 <= w_MWB_III_1945_59_dh Integer
# 0 <= w_MWB_III_1945_59_fossil Integer
# 0 <= w_MWB_III_1945_59_hp Integer
# 0 <= w_MWB_III_1945_59_reno_biogene Integer
# 0 <= w_MWB_III_1945_59_reno_dh Integer
# 0 <= w_MWB_III_1945_59_reno_fossil Integer
# 0 <= w_MWB_III_1945_59_reno_hp Integer
# 0 <= w_MWB_II_1920_44_biogene Integer
# 0 <= w_MWB_II_1920_44_dh Integer
# 0 <= w_MWB_II_1920_44_fossil Integer
# 0 <= w_MWB_II_1920_44_hp Integer
# 0 <= w_MWB_II_1920_44_reno_biogene Integer
# 0 <= w_MWB_II_1920_44_reno_dh Integer
# 0 <= w_MWB_II_1920_44_reno_fossil Integer
# 0 <= w_MWB_II_1920_44_reno_hp Integer
# 0 <= w_MWB_IV_1960_79_biogene Integer
# 0 <= w_MWB_IV_1960_79_dh Integer
# 0 <= w_MWB_IV_1960_79_fossil Integer
# 0 <= w_MWB_IV_1960_79_hp Integer
# 0 <= w_MWB_IV_1960_79_reno_biogene Integer
# 0 <= w_MWB_IV_1960_79_reno_dh Integer
# 0 <= w_MWB_IV_1960_79_reno_fossil Integer
# 0 <= w_MWB_IV_1960_79_reno_hp Integer
# 0 <= w_MWB_I_Bis_1919_biogene Integer
# 0 <= w_MWB_I_Bis_1919_dh Integer
# 0 <= w_MWB_I_Bis_1919_fossil Integer
# 0 <= w_MWB_I_Bis_1919_hp Integer
# 0 <= w_MWB_I_Bis_1919_reno_biogene Integer
# 0 <= w_MWB_I_Bis_1919_reno_dh Integer
# 0 <= w_MWB_I_Bis_1919_reno_fossil Integer
# 0 <= w_MWB_I_Bis_1919_reno_hp Integer
# 0 <= w_MWB_VIII__2020_biogene Integer
# 0 <= w_MWB_VIII__2020_dh Integer
# 0 <= w_MWB_VIII__2020_fossil Integer
# 0 <= w_MWB_VIII__2020_hp Integer
# 0 <= w_MWB_VII_2000_20_biogene Integer
# 0 <= w_MWB_VII_2000_20_dh Integer
# 0 <= w_MWB_VII_2000_20_fossil Integer
# 0 <= w_MWB_VII_2000_20_hp Integer
# 0 <= w_MWB_VI_1990_99_biogene Integer
# 0 <= w_MWB_VI_1990_99_dh Integer
# 0 <= w_MWB_VI_1990_99_fossil Integer
# 0 <= w_MWB_VI_1990_99_hp Integer
# 0 <= w_MWB_VI_1990_99_reno_biogene Integer
# 0 <= w_MWB_VI_1990_99_reno_dh Integer
# 0 <= w_MWB_VI_1990_99_reno_fossil Integer
# 0 <= w_MWB_VI_1990_99_reno_hp Integer
# 0 <= w_MWB_V_1980_89_biogene Integer
# 0 <= w_MWB_V_1980_89_dh Integer
# 0 <= w_MWB_V_1980_89_fossil Integer
# 0 <= w_MWB_V_1980_89_hp Integer
# 0 <= w_MWB_V_1980_89_reno_biogene Integer
# 0 <= w_MWB_V_1980_89_reno_dh Integer
# 0 <= w_MWB_V_1980_89_reno_fossil Integer
# 0 <= w_MWB_V_1980_89_reno_hp Integer
# 0 <= w_RH_III_1945_59_biogene Integer
# 0 <= w_RH_III_1945_59_dh Integer
# 0 <= w_RH_III_1945_59_fossil Integer
# 0 <= w_RH_III_1945_59_hp Integer
# 0 <= w_RH_III_1945_59_reno_biogene Integer
# 0 <= w_RH_III_1945_59_reno_dh Integer
# 0 <= w_RH_III_1945_59_reno_fossil Integer
# 0 <= w_RH_III_1945_59_reno_hp Integer
# 0 <= w_RH_II_1920_44_biogene Integer
# 0 <= w_RH_II_1920_44_dh Integer
# 0 <= w_RH_II_1920_44_fossil Integer
# 0 <= w_RH_II_1920_44_hp Integer
# 0 <= w_RH_II_1920_44_reno_biogene Integer
# 0 <= w_RH_II_1920_44_reno_dh Integer
# 0 <= w_RH_II_1920_44_reno_fossil Integer
# 0 <= w_RH_II_1920_44_reno_hp Integer
# 0 <= w_RH_IV_1960_79_biogene Integer
# 0 <= w_RH_IV_1960_79_dh Integer
# 0 <= w_RH_IV_1960_79_fossil Integer
# 0 <= w_RH_IV_1960_79_hp Integer
# 0 <= w_RH_IV_1960_79_reno_biogene Integer
# 0 <= w_RH_IV_1960_79_reno_dh Integer
# 0 <= w_RH_IV_1960_79_reno_fossil Integer
# 0 <= w_RH_IV_1960_79_reno_hp Integer
# 0 <= w_RH_I_Bis_1919_biogene Integer
# 0 <= w_RH_I_Bis_1919_dh Integer
# 0 <= w_RH_I_Bis_1919_fossil Integer
# 0 <= w_RH_I_Bis_1919_hp Integer
# 0 <= w_RH_I_Bis_1919_reno_biogene Integer
# 0 <= w_RH_I_Bis_1919_reno_dh Integer
# 0 <= w_RH_I_Bis_1919_reno_fossil Integer
# 0 <= w_RH_I_Bis_1919_reno_hp Integer
# 0 <= w_RH_VIII__2020_biogene Integer
# 0 <= w_RH_VIII__2020_dh Integer
# 0 <= w_RH_VIII__2020_fossil Integer
# 0 <= w_RH_VIII__2020_hp Integer
# 0 <= w_RH_VII_2000_20_biogene Integer
# 0 <= w_RH_VII_2000_20_dh Integer
# 0 <= w_RH_VII_2000_20_fossil Integer
# 0 <= w_RH_VII_2000_20_hp Integer
# 0 <= w_RH_VI_1990_99_biogene Integer
# 0 <= w_RH_VI_1990_99_dh Integer
# 0 <= w_RH_VI_1990_99_fossil Integer
# 0 <= w_RH_VI_1990_99_hp Integer
# 0 <= w_RH_VI_1990_99_reno_biogene Integer
# 0 <= w_RH_VI_1990_99_reno_dh Integer
# 0 <= w_RH_VI_1990_99_reno_fossil Integer
# 0 <= w_RH_VI_1990_99_reno_hp Integer
# 0 <= w_RH_V_1980_89_biogene Integer
# 0 <= w_RH_V_1980_89_dh Integer
# 0 <= w_RH_V_1980_89_fossil Integer
# 0 <= w_RH_V_1980_89_hp Integer
# 0 <= w_RH_V_1980_89_reno_biogene Integer
# 0 <= w_RH_V_1980_89_reno_dh Integer
# 0 <= w_RH_V_1980_89_reno_fossil Integer
# 0 <= w_RH_V_1980_89_reno_hp Integer

# %%
# ---------------------------------------------------
# 6) Lösen
# ---------------------------------------------------
solver = pl.PULP_CBC_CMD(timeLimit=1) # Zeitlimit in Sekunden; best-effort Lösung; wenn exakter gewünscht, Zeitlimit entfernen
model.solve(solver)

print("Status:", pl.LpStatus[model.status])
w_sol = pd.Series({i: w[i].varValue for i in idx})
# Out:
# Status: Optimal

# %%
w_sol
# Out:
# EFH I_Bis 1919_fossil      0.0
# EFH II_1920-44_fossil      0.0
# EFH III_1945-59_fossil     0.0
# EFH IV_1960-79_fossil      0.0
# EFH V_1980-89_fossil       0.0
#                           ...
# MWB II_1920-44_reno_hp     0.0
# MWB III_1945-59_reno_hp    0.0
# MWB IV_1960-79_reno_hp     0.0
# MWB V_1980-89_reno_hp      0.0
# MWB VI_1990-99_reno_hp     0.0
# Length: 228, dtype: float64

# %%
# ---------------------------------------------------
# 7) Analyse: Ziel vs. Modell
# ---------------------------------------------------
Af = df["Af_m2"]
usage = df["usage_simplified"]
carrier = df["energy_carrier_primary"]
E_therm = df["E_therm_MWhyr"]

Af_tot_model = float((w_sol * Af).sum())
Af_res_model = float((w_sol[usage == "residential"] * Af[usage == "residential"]).sum())
share_res_model = Af_res_model / Af_tot_model if Af_tot_model != 0 else None

results = []

# Af_total
Af_target = targets["Af_total"]
results.append({
    "constraint": "Af_total",
    "metric": "Af_sum",
    "target": Af_target,
    "model": Af_tot_model,
    "abs_error": Af_tot_model - Af_target,
    "rel_error": (Af_tot_model - Af_target) / Af_target if Af_target != 0 else None,
})

# share_residential_Af
share_res_target = targets["share_residential_Af"]
results.append({
    "constraint": "share_residential_Af",
    "metric": "share_residential_Af",
    "target": share_res_target,
    "model": share_res_model,
    "abs_error": share_res_model - share_res_target,
    "rel_error": (share_res_model - share_res_target) / share_res_target if share_res_target != 0 else None,
})

# share_energy_therm
share_energy_targets = targets["share_energy_therm"]
for cat_name, share_target in share_energy_targets.items():
    mask = carrier == cat_name
    E_cat = float((w_sol[mask.index] * E_therm[mask]).sum())
    share_model = E_cat / float((w_sol * E_therm).sum()) if float((w_sol * E_therm).sum()) != 0 else None

    results.append({
        "constraint": f"share_energy_therm_{cat_name}",
        "metric": f"share_energy_therm_{cat_name}",
        "target": share_target,
        "model": share_model,
        "abs_error": share_model - share_target,
        "rel_error": (share_model - share_target) / share_target if share_target != 0 else None,
    })

res_df = pd.DataFrame(results)
print(res_df)

# einfache Spaltendiagramme
for _, row in res_df.iterrows():
    metric = row["metric"]
    values = [row["target"], row["model"]]
    labels = ["target", "model"]

    plt.figure()
    plt.bar(labels, values, color=["tab:blue", "tab:orange"])
    plt.title(metric)
    plt.ylabel("value")
    plt.grid(axis="y", alpha=0.3)
    plt.tight_layout()
    plt.show()
# Out:
#                          constraint                            metric  \
# 0                          Af_total                            Af_sum
# 1              share_residential_Af              share_residential_Af
# 2         share_energy_therm_fossil         share_energy_therm_fossil
# 3        share_energy_therm_biogene        share_energy_therm_biogene
# 4  share_energy_therm_district_heat  share_energy_therm_district_heat
# 5      share_energy_therm_heat_pump      share_energy_therm_heat_pump
#
#       target          model  abs_error  rel_error
# 0  878085.00  878123.040000  38.040000   0.000043
# 1       0.61       0.609338  -0.000662  -0.001085
# 2       0.31       0.309995  -0.000005  -0.000015
# 3       0.37       0.369998  -0.000002  -0.000006
# 4       0.16       0.000000  -0.160000  -1.000000
# 5       0.15       0.000000  -0.150000  -1.000000
